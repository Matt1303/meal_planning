# %%
pip install pytest
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pytest test_recipe_extractor.py
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.7, pytest-7.4.4, pluggy-1.0.0
# rootdir: /Users/Matt/DEZoomcamp/meal_planning
# plugins: anyio-4.2.0
# collected 6 items
#
# test_recipe_extractor.py .F.F..                                          [100%]
#
# =================================== FAILURES ===================================
# _________________ TestRecipeExtractor.test_filter_ingredients __________________
#
# self = <test_recipe_extractor.TestRecipeExtractor testMethod=test_filter_ingredients>
#
#     def test_filter_ingredients(self):
#         final_ingredients = ['1 cup sugar', '2 cups Flour']
#         extractor = RecipeExtractor('test_dir')
#         filtered_ingredients = extractor.filter_ingredients(final_ingredients)
# >       self.assertEqual(filtered_ingredients, ['1 cup sugar'])
# E       AssertionError: Lists differ: ['1 cup sugar', '2 cups Flour'] != ['1 cup sugar']
# E
# ...
